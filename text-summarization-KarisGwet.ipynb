# %% [markdown]
# ## Text Summary with tf-ifd

# %% [markdown]
# ### This exercise serves as an example to one of the usecases of tf-idf, which is summarizing a text document

# %%
import math
from nltk import sent_tokenize, word_tokenize, PorterStemmer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer

# %% [markdown]
# #### import our text and tokenize the sentences
# #### Note that in this exercise, we are tokenizing by sentence, and not words. This is to ensure a meaningful output.

# %%
text = open('news.txt','r').read()
sentences = sent_tokenize(text)
total_documents = len(sentences)
print(total_documents)
print(sentences)
# Out:
# 11
# ['British Airways and budget rival Ryanair have cancelled hundreds of flights as demand for travel drops amid fears about the spread of coronavirus.', 'BA is cancelling 216 flights from 16-28 March from London to destinations including New York, Italy, France, Austria, Belgium, Germany and Ireland.', 'Ryanair will cut up to 25% of flights in and out of Italy from 17 March to 8 April.', 'Tourists and business people are cutting back on foreign travel.', 'There could be a "very significant expansion" of the number of cases of coronavirus in the UK, Prime Minister Boris Johnson has warned.', 'Ryanair boss Michael O\'Leary said: "Our focus at this time is on minimising any risk to our people and our passengers.', '"While we are heavily booked over the next two weeks, there has been a notable drop in forward bookings towards the end of March, into early April.', '"It makes sense to selectively prune our schedule to and from those airports where travel has been most affected by the Covid-19 outbreak."', 'The firm declined to say how many flights or passengers would be affected.', 'However, it said the move would not affect its results for the financial year which ends on 31 March.', 'British Airways said it would contact customers on cancelled flights to offer rebooking on to other carriers, refunds or another flight with BA for a later date of travel.']

# %% [markdown]
# ### Create the Frequency matrix of the words in each sentence

# %%
def _create_frequency_matrix(sentences):
    frequency_matrix = {}
    stopWords = set(stopwords.words("english"))
    ps = PorterStemmer()

    for sent in sentences:
        # counts frequencies of words in every sentence
        freq_table = {}
        words = word_tokenize(sent)

        for word in words:
            #stopwords removal
            if word in stopWords or len(word) < 2 or not word.isalpha():
                continue
            # stemming and lowercasing
            word = ps.stem(word.lower())
            if word not in freq_table:
                freq_table[word] = 0
            freq_table[word] += 1
        
        #save frequencies as sent -> word_frequencies
        frequency_matrix[sent] = freq_table

    return frequency_matrix

# %%
t = [word for word in word_tokenize(sentences[0]) if word not in stopwords.words("english") and word.isalpha()]
t
# Out:
# ['British',
#  'Airways',
#  'budget',
#  'rival',
#  'Ryanair',
#  'cancelled',
#  'hundreds',
#  'flights',
#  'demand',
#  'travel',
#  'drops',
#  'amid',
#  'fears',
#  'spread',
#  'coronavirus']

# %%
frequency_matrix = _create_frequency_matrix(sentences)
frequency_matrix
# Out:
# {'British Airways and budget rival Ryanair have cancelled hundreds of flights as demand for travel drops amid fears about the spread of coronavirus.': {'british': 1,
#   'airway': 1,
#   'budget': 1,
#   'rival': 1,
#   'ryanair': 1,
#   'cancel': 1,
#   'hundr': 1,
#   'flight': 1,
#   'demand': 1,
#   'travel': 1,
#   'drop': 1,
#   'amid': 1,
#   'fear': 1,
#   'spread': 1,
#   'coronaviru': 1},
#  'BA is cancelling 216 flights from 16-28 March from London to destinations including New York, Italy, France, Austria, Belgium, Germany and Ireland.': {'ba': 1,
#   'cancel': 1,
#   'flight': 1,
#   'march': 1,
#   'london': 1,
#   'destin': 1,
#   'includ': 1,
#   'new': 1,
#   'york': 1,
#   'itali': 1,
#   'franc': 1,
#   'austria': 1,
#   'belgium': 1,
#   'germani': 1,
#   'ireland': 1},
#  'Ryanair will cut up to 25% of flights in and out of Italy from 17 March to 8 April.': {'ryanair': 1,
#   'cut': 1,
#   'flight': 1,
#   'itali': 1,
#   'march': 1,
#   'april': 1},
#  'Tourists and business people are cutting back on foreign travel.': {'tourist': 1,
#   'busi': 1,
#   'peopl': 1,
#   'cut': 1,
#   'back': 1,
#   'foreign': 1,
#   'travel': 1},
#  'There could be a "very significant expansion" of the number of cases of coronavirus in the UK, Prime Minister Boris Johnson has warned.': {'there': 1,
#   'could': 1,
#   'signific': 1,
#   'expans': 1,
#   'number': 1,
#   'case': 1,
#   'coronaviru': 1,
#   'uk': 1,
#   'prime': 1,
#   'minist': 1,
#   'bori': 1,
#   'johnson': 1,
#   'warn': 1},
#  'Ryanair boss Michael O\'Leary said: "Our focus at this time is on minimising any risk to our people and our passengers.': {'ryanair': 1,
#   'boss': 1,
#   'michael': 1,
#   'said': 1,
#   'our': 1,
#   'focu': 1,
#   'time': 1,
#   'minimis': 1,
#   'risk': 1,
#   'peopl': 1,
#   'passeng': 1},
#  '"While we are heavily booked over the next two weeks, there has been a notable drop in forward bookings towards the end of March, into early April.': {'while': 1,
#   'heavili': 1,
#   'book': 2,
#   'next': 1,
#   'two': 1,
#   'week': 1,
#   'notabl': 1,
#   'drop': 1,
#   'forward': 1,
#   'toward': 1,
#   'end': 1,
#   'march': 1,
#   'earli': 1,
#   'april': 1},
#  '"It makes sense to selectively prune our schedule to and from those airports where travel has been most affected by the Covid-19 outbreak."': {'it': 1,
#   'make': 1,
#   'sens': 1,
#   'select': 1,
#   'prune': 1,
#   'schedul': 1,
#   'airport': 1,
#   'travel': 1,
#   'affect': 1,
#   'outbreak': 1},
#  'The firm declined to say how many flights or passengers would be affected.': {'the': 1,
#   'firm': 1,
#   'declin': 1,
#   'say': 1,
#   'mani': 1,
#   'flight': 1,
#   'passeng': 1,
#   'would': 1,
#   'affect': 1},
#  'However, it said the move would not affect its results for the financial year which ends on 31 March.': {'howev': 1,
#   'said': 1,
#   'move': 1,
#   'would': 1,
#   'affect': 1,
#   'result': 1,
#   'financi': 1,
#   'year': 1,
#   'end': 1,
#   'march': 1},
#  'British Airways said it would contact customers on cancelled flights to offer rebooking on to other carriers, refunds or another flight with BA for a later date of travel.': {'british': 1,
#   'airway': 1,
#   'said': 1,
#   'would': 1,
#   'contact': 1,
#   'custom': 1,
#   'cancel': 1,
#   'flight': 2,
#   'offer': 1,
#   'rebook': 1,
#   'carrier': 1,
#   'refund': 1,
#   'anoth': 1,
#   'ba': 1,
#   'later': 1,
#   'date': 1,
#   'travel': 1}}

# %% [markdown]
# ### Calculate TermFrequency for each word

# %%
def _create_tf_matrix(freq_matrix):
    tf_matrix = {}

    for sent, f_table in freq_matrix.items():
        tf_table = {}

        count_words_in_sentence = len(f_table)
        for word, count in f_table.items():
            tf_table[word] = count / count_words_in_sentence

        tf_matrix[sent] = tf_table

    return tf_matrix

# %%
tf_matrix = _create_tf_matrix(frequency_matrix)
tf_matrix
# Out:
# {'British Airways and budget rival Ryanair have cancelled hundreds of flights as demand for travel drops amid fears about the spread of coronavirus.': {'british': 0.06666666666666667,
#   'airway': 0.06666666666666667,
#   'budget': 0.06666666666666667,
#   'rival': 0.06666666666666667,
#   'ryanair': 0.06666666666666667,
#   'cancel': 0.06666666666666667,
#   'hundr': 0.06666666666666667,
#   'flight': 0.06666666666666667,
#   'demand': 0.06666666666666667,
#   'travel': 0.06666666666666667,
#   'drop': 0.06666666666666667,
#   'amid': 0.06666666666666667,
#   'fear': 0.06666666666666667,
#   'spread': 0.06666666666666667,
#   'coronaviru': 0.06666666666666667},
#  'BA is cancelling 216 flights from 16-28 March from London to destinations including New York, Italy, France, Austria, Belgium, Germany and Ireland.': {'ba': 0.06666666666666667,
#   'cancel': 0.06666666666666667,
#   'flight': 0.06666666666666667,
#   'march': 0.06666666666666667,
#   'london': 0.06666666666666667,
#   'destin': 0.06666666666666667,
#   'includ': 0.06666666666666667,
#   'new': 0.06666666666666667,
#   'york': 0.06666666666666667,
#   'itali': 0.06666666666666667,
#   'franc': 0.06666666666666667,
#   'austria': 0.06666666666666667,
#   'belgium': 0.06666666666666667,
#   'germani': 0.06666666666666667,
#   'ireland': 0.06666666666666667},
#  'Ryanair will cut up to 25% of flights in and out of Italy from 17 March to 8 April.': {'ryanair': 0.16666666666666666,
#   'cut': 0.16666666666666666,
#   'flight': 0.16666666666666666,
#   'itali': 0.16666666666666666,
#   'march': 0.16666666666666666,
#   'april': 0.16666666666666666},
#  'Tourists and business people are cutting back on foreign travel.': {'tourist': 0.14285714285714285,
#   'busi': 0.14285714285714285,
#   'peopl': 0.14285714285714285,
#   'cut': 0.14285714285714285,
#   'back': 0.14285714285714285,
#   'foreign': 0.14285714285714285,
#   'travel': 0.14285714285714285},
#  'There could be a "very significant expansion" of the number of cases of coronavirus in the UK, Prime Minister Boris Johnson has warned.': {'there': 0.07692307692307693,
#   'could': 0.07692307692307693,
#   'signific': 0.07692307692307693,
#   'expans': 0.07692307692307693,
#   'number': 0.07692307692307693,
#   'case': 0.07692307692307693,
#   'coronaviru': 0.07692307692307693,
#   'uk': 0.07692307692307693,
#   'prime': 0.07692307692307693,
#   'minist': 0.07692307692307693,
#   'bori': 0.07692307692307693,
#   'johnson': 0.07692307692307693,
#   'warn': 0.07692307692307693},
#  'Ryanair boss Michael O\'Leary said: "Our focus at this time is on minimising any risk to our people and our passengers.': {'ryanair': 0.09090909090909091,
#   'boss': 0.09090909090909091,
#   'michael': 0.09090909090909091,
#   'said': 0.09090909090909091,
#   'our': 0.09090909090909091,
#   'focu': 0.09090909090909091,
#   'time': 0.09090909090909091,
#   'minimis': 0.09090909090909091,
#   'risk': 0.09090909090909091,
#   'peopl': 0.09090909090909091,
#   'passeng': 0.09090909090909091},
#  '"While we are heavily booked over the next two weeks, there has been a notable drop in forward bookings towards the end of March, into early April.': {'while': 0.07142857142857142,
#   'heavili': 0.07142857142857142,
#   'book': 0.14285714285714285,
#   'next': 0.07142857142857142,
#   'two': 0.07142857142857142,
#   'week': 0.07142857142857142,
#   'notabl': 0.07142857142857142,
#   'drop': 0.07142857142857142,
#   'forward': 0.07142857142857142,
#   'toward': 0.07142857142857142,
#   'end': 0.07142857142857142,
#   'march': 0.07142857142857142,
#   'earli': 0.07142857142857142,
#   'april': 0.07142857142857142},
#  '"It makes sense to selectively prune our schedule to and from those airports where travel has been most affected by the Covid-19 outbreak."': {'it': 0.1,
#   'make': 0.1,
#   'sens': 0.1,
#   'select': 0.1,
#   'prune': 0.1,
#   'schedul': 0.1,
#   'airport': 0.1,
#   'travel': 0.1,
#   'affect': 0.1,
#   'outbreak': 0.1},
#  'The firm declined to say how many flights or passengers would be affected.': {'the': 0.1111111111111111,
#   'firm': 0.1111111111111111,
#   'declin': 0.1111111111111111,
#   'say': 0.1111111111111111,
#   'mani': 0.1111111111111111,
#   'flight': 0.1111111111111111,
#   'passeng': 0.1111111111111111,
#   'would': 0.1111111111111111,
#   'affect': 0.1111111111111111},
#  'However, it said the move would not affect its results for the financial year which ends on 31 March.': {'howev': 0.1,
#   'said': 0.1,
#   'move': 0.1,
#   'would': 0.1,
#   'affect': 0.1,
#   'result': 0.1,
#   'financi': 0.1,
#   'year': 0.1,
#   'end': 0.1,
#   'march': 0.1},
#  'British Airways said it would contact customers on cancelled flights to offer rebooking on to other carriers, refunds or another flight with BA for a later date of travel.': {'british': 0.058823529411764705,
#   'airway': 0.058823529411764705,
#   'said': 0.058823529411764705,
#   'would': 0.058823529411764705,
#   'contact': 0.058823529411764705,
#   'custom': 0.058823529411764705,
#   'cancel': 0.058823529411764705,
#   'flight': 0.11764705882352941,
#   'offer': 0.058823529411764705,
#   'rebook': 0.058823529411764705,
#   'carrier': 0.058823529411764705,
#   'refund': 0.058823529411764705,
#   'anoth': 0.058823529411764705,
#   'ba': 0.058823529411764705,
#   'later': 0.058823529411764705,
#   'date': 0.058823529411764705,
#   'travel': 0.058823529411764705}}

# %% [markdown]
# ### Counting how many sentences (documents) contain a specific word

# %%
def _create_documents_per_words(freq_matrix):
    word_per_doc_table = {}

    for sent, f_table in freq_matrix.items():
        for word, count in f_table.items():
            if word in word_per_doc_table:
                word_per_doc_table[word] += 1
            else:
                word_per_doc_table[word] = 1

    return word_per_doc_table

# %%
sentences = sent_tokenize(text)
documents_per_words = _create_documents_per_words(frequency_matrix)
documents_per_words
# Out:
# {'british': 2,
#  'airway': 2,
#  'budget': 1,
#  'rival': 1,
#  'ryanair': 3,
#  'cancel': 3,
#  'hundr': 1,
#  'flight': 5,
#  'demand': 1,
#  'travel': 4,
#  'drop': 2,
#  'amid': 1,
#  'fear': 1,
#  'spread': 1,
#  'coronaviru': 2,
#  'ba': 2,
#  'march': 4,
#  'london': 1,
#  'destin': 1,
#  'includ': 1,
#  'new': 1,
#  'york': 1,
#  'itali': 2,
#  'franc': 1,
#  'austria': 1,
#  'belgium': 1,
#  'germani': 1,
#  'ireland': 1,
#  'cut': 2,
#  'april': 2,
#  'tourist': 1,
#  'busi': 1,
#  'peopl': 2,
#  'back': 1,
#  'foreign': 1,
#  'there': 1,
#  'could': 1,
#  'signific': 1,
#  'expans': 1,
#  'number': 1,
#  'case': 1,
#  'uk': 1,
#  'prime': 1,
#  'minist': 1,
#  'bori': 1,
#  'johnson': 1,
#  'warn': 1,
#  'boss': 1,
#  'michael': 1,
#  'said': 3,
#  'our': 1,
#  'focu': 1,
#  'time': 1,
#  'minimis': 1,
#  'risk': 1,
#  'passeng': 2,
#  'while': 1,
#  'heavili': 1,
#  'book': 1,
#  'next': 1,
#  'two': 1,
#  'week': 1,
#  'notabl': 1,
#  'forward': 1,
#  'toward': 1,
#  'end': 2,
#  'earli': 1,
#  'it': 1,
#  'make': 1,
#  'sens': 1,
#  'select': 1,
#  'prune': 1,
#  'schedul': 1,
#  'airport': 1,
#  'affect': 3,
#  'outbreak': 1,
#  'the': 1,
#  'firm': 1,
#  'declin': 1,
#  'say': 1,
#  'mani': 1,
#  'would': 3,
#  'howev': 1,
#  'move': 1,
#  'result': 1,
#  'financi': 1,
#  'year': 1,
#  'contact': 1,
#  'custom': 1,
#  'offer': 1,
#  'rebook': 1,
#  'carrier': 1,
#  'refund': 1,
#  'anoth': 1,
#  'later': 1,
#  'date': 1}

# %% [markdown]
# ### Calculate IDF

# %%
def _create_idf_matrix(freq_matrix, count_doc_per_words, total_documents):
    idf_matrix = {}

    for sent, f_table in freq_matrix.items():
        idf_table = {}

        for word in f_table.keys():
            idf_table[word] = math.log10(total_documents / float(count_doc_per_words[word]))

        idf_matrix[sent] = idf_table

    return idf_matrix

# %%
idf_matrix = _create_idf_matrix(frequency_matrix, documents_per_words, total_documents)
idf_matrix
# Out:
# {'British Airways and budget rival Ryanair have cancelled hundreds of flights as demand for travel drops amid fears about the spread of coronavirus.': {'british': 0.7403626894942439,
#   'airway': 0.7403626894942439,
#   'budget': 1.0413926851582251,
#   'rival': 1.0413926851582251,
#   'ryanair': 0.5642714304385625,
#   'cancel': 0.5642714304385625,
#   'hundr': 1.0413926851582251,
#   'flight': 0.3424226808222063,
#   'demand': 1.0413926851582251,
#   'travel': 0.43933269383026263,
#   'drop': 0.7403626894942439,
#   'amid': 1.0413926851582251,
#   'fear': 1.0413926851582251,
#   'spread': 1.0413926851582251,
#   'coronaviru': 0.7403626894942439},
#  'BA is cancelling 216 flights from 16-28 March from London to destinations including New York, Italy, France, Austria, Belgium, Germany and Ireland.': {'ba': 0.7403626894942439,
#   'cancel': 0.5642714304385625,
#   'flight': 0.3424226808222063,
#   'march': 0.43933269383026263,
#   'london': 1.0413926851582251,
#   'destin': 1.0413926851582251,
#   'includ': 1.0413926851582251,
#   'new': 1.0413926851582251,
#   'york': 1.0413926851582251,
#   'itali': 0.7403626894942439,
#   'franc': 1.0413926851582251,
#   'austria': 1.0413926851582251,
#   'belgium': 1.0413926851582251,
#   'germani': 1.0413926851582251,
#   'ireland': 1.0413926851582251},
#  'Ryanair will cut up to 25% of flights in and out of Italy from 17 March to 8 April.': {'ryanair': 0.5642714304385625,
#   'cut': 0.7403626894942439,
#   'flight': 0.3424226808222063,
#   'itali': 0.7403626894942439,
#   'march': 0.43933269383026263,
#   'april': 0.7403626894942439},
#  'Tourists and business people are cutting back on foreign travel.': {'tourist': 1.0413926851582251,
#   'busi': 1.0413926851582251,
#   'peopl': 0.7403626894942439,
#   'cut': 0.7403626894942439,
#   'back': 1.0413926851582251,
#   'foreign': 1.0413926851582251,
#   'travel': 0.43933269383026263},
#  'There could be a "very significant expansion" of the number of cases of coronavirus in the UK, Prime Minister Boris Johnson has warned.': {'there': 1.0413926851582251,
#   'could': 1.0413926851582251,
#   'signific': 1.0413926851582251,
#   'expans': 1.0413926851582251,
#   'number': 1.0413926851582251,
#   'case': 1.0413926851582251,
#   'coronaviru': 0.7403626894942439,
#   'uk': 1.0413926851582251,
#   'prime': 1.0413926851582251,
#   'minist': 1.0413926851582251,
#   'bori': 1.0413926851582251,
#   'johnson': 1.0413926851582251,
#   'warn': 1.0413926851582251},
#  'Ryanair boss Michael O\'Leary said: "Our focus at this time is on minimising any risk to our people and our passengers.': {'ryanair': 0.5642714304385625,
#   'boss': 1.0413926851582251,
#   'michael': 1.0413926851582251,
#   'said': 0.5642714304385625,
#   'our': 1.0413926851582251,
#   'focu': 1.0413926851582251,
#   'time': 1.0413926851582251,
#   'minimis': 1.0413926851582251,
#   'risk': 1.0413926851582251,
#   'peopl': 0.7403626894942439,
#   'passeng': 0.7403626894942439},
#  '"While we are heavily booked over the next two weeks, there has been a notable drop in forward bookings towards the end of March, into early April.': {'while': 1.0413926851582251,
#   'heavili': 1.0413926851582251,
#   'book': 1.0413926851582251,
#   'next': 1.0413926851582251,
#   'two': 1.0413926851582251,
#   'week': 1.0413926851582251,
#   'notabl': 1.0413926851582251,
#   'drop': 0.7403626894942439,
#   'forward': 1.0413926851582251,
#   'toward': 1.0413926851582251,
#   'end': 0.7403626894942439,
#   'march': 0.43933269383026263,
#   'earli': 1.0413926851582251,
#   'april': 0.7403626894942439},
#  '"It makes sense to selectively prune our schedule to and from those airports where travel has been most affected by the Covid-19 outbreak."': {'it': 1.0413926851582251,
#   'make': 1.0413926851582251,
#   'sens': 1.0413926851582251,
#   'select': 1.0413926851582251,
#   'prune': 1.0413926851582251,
#   'schedul': 1.0413926851582251,
#   'airport': 1.0413926851582251,
#   'travel': 0.43933269383026263,
#   'affect': 0.5642714304385625,
#   'outbreak': 1.0413926851582251},
#  'The firm declined to say how many flights or passengers would be affected.': {'the': 1.0413926851582251,
#   'firm': 1.0413926851582251,
#   'declin': 1.0413926851582251,
#   'say': 1.0413926851582251,
#   'mani': 1.0413926851582251,
#   'flight': 0.3424226808222063,
#   'passeng': 0.7403626894942439,
#   'would': 0.5642714304385625,
#   'affect': 0.5642714304385625},
#  'However, it said the move would not affect its results for the financial year which ends on 31 March.': {'howev': 1.0413926851582251,
#   'said': 0.5642714304385625,
#   'move': 1.0413926851582251,
#   'would': 0.5642714304385625,
#   'affect': 0.5642714304385625,
#   'result': 1.0413926851582251,
#   'financi': 1.0413926851582251,
#   'year': 1.0413926851582251,
#   'end': 0.7403626894942439,
#   'march': 0.43933269383026263},
#  'British Airways said it would contact customers on cancelled flights to offer rebooking on to other carriers, refunds or another flight with BA for a later date of travel.': {'british': 0.7403626894942439,
#   'airway': 0.7403626894942439,
#   'said': 0.5642714304385625,
#   'would': 0.5642714304385625,
#   'contact': 1.0413926851582251,
#   'custom': 1.0413926851582251,
#   'cancel': 0.5642714304385625,
#   'flight': 0.3424226808222063,
#   'offer': 1.0413926851582251,
#   'rebook': 1.0413926851582251,
#   'carrier': 1.0413926851582251,
#   'refund': 1.0413926851582251,
#   'anoth': 1.0413926851582251,
#   'ba': 0.7403626894942439,
#   'later': 1.0413926851582251,
#   'date': 1.0413926851582251,
#   'travel': 0.43933269383026263}}

# %% [markdown]
# ### Calculate TF-IDF

# %%
def _create_tf_idf_matrix(tf_matrix, idf_matrix):
    tf_idf_matrix = {}

    for (sent1, f_table1), (sent2, f_table2) in zip(tf_matrix.items(), idf_matrix.items()):

        tf_idf_table = {}

        for (word1, value1), (word2, value2) in zip(f_table1.items(),
                                                    f_table2.items()):  # here, keys are the same in both the table
            tf_idf_table[word1] = float(value1 * value2)

        tf_idf_matrix[sent1] = tf_idf_table

    return tf_idf_matrix

# %%
tf_idf_matrix = _create_tf_idf_matrix(tf_matrix, idf_matrix)
tf_idf_matrix
# Out:
# {'British Airways and budget rival Ryanair have cancelled hundreds of flights as demand for travel drops amid fears about the spread of coronavirus.': {'british': 0.049357512632949595,
#   'airway': 0.049357512632949595,
#   'budget': 0.06942617901054834,
#   'rival': 0.06942617901054834,
#   'ryanair': 0.03761809536257084,
#   'cancel': 0.03761809536257084,
#   'hundr': 0.06942617901054834,
#   'flight': 0.022828178721480418,
#   'demand': 0.06942617901054834,
#   'travel': 0.02928884625535084,
#   'drop': 0.049357512632949595,
#   'amid': 0.06942617901054834,
#   'fear': 0.06942617901054834,
#   'spread': 0.06942617901054834,
#   'coronaviru': 0.049357512632949595},
#  'BA is cancelling 216 flights from 16-28 March from London to destinations including New York, Italy, France, Austria, Belgium, Germany and Ireland.': {'ba': 0.049357512632949595,
#   'cancel': 0.03761809536257084,
#   'flight': 0.022828178721480418,
#   'march': 0.02928884625535084,
#   'london': 0.06942617901054834,
#   'destin': 0.06942617901054834,
#   'includ': 0.06942617901054834,
#   'new': 0.06942617901054834,
#   'york': 0.06942617901054834,
#   'itali': 0.049357512632949595,
#   'franc': 0.06942617901054834,
#   'austria': 0.06942617901054834,
#   'belgium': 0.06942617901054834,
#   'germani': 0.06942617901054834,
#   'ireland': 0.06942617901054834},
#  'Ryanair will cut up to 25% of flights in and out of Italy from 17 March to 8 April.': {'ryanair': 0.09404523840642709,
#   'cut': 0.12339378158237398,
#   'flight': 0.05707044680370105,
#   'itali': 0.12339378158237398,
#   'march': 0.0732221156383771,
#   'april': 0.12339378158237398},
#  'Tourists and business people are cutting back on foreign travel.': {'tourist': 0.14877038359403216,
#   'busi': 0.14877038359403216,
#   'peopl': 0.10576609849917769,
#   'cut': 0.10576609849917769,
#   'back': 0.14877038359403216,
#   'foreign': 0.14877038359403216,
#   'travel': 0.06276181340432323},
#  'There could be a "very significant expansion" of the number of cases of coronavirus in the UK, Prime Minister Boris Johnson has warned.': {'there': 0.08010712962755578,
#   'could': 0.08010712962755578,
#   'signific': 0.08010712962755578,
#   'expans': 0.08010712962755578,
#   'number': 0.08010712962755578,
#   'case': 0.08010712962755578,
#   'coronaviru': 0.05695097611494184,
#   'uk': 0.08010712962755578,
#   'prime': 0.08010712962755578,
#   'minist': 0.08010712962755578,
#   'bori': 0.08010712962755578,
#   'johnson': 0.08010712962755578,
#   'warn': 0.08010712962755578},
#  'Ryanair boss Michael O\'Leary said: "Our focus at this time is on minimising any risk to our people and our passengers.': {'ryanair': 0.05129740276714205,
#   'boss': 0.09467206228711138,
#   'michael': 0.09467206228711138,
#   'said': 0.05129740276714205,
#   'our': 0.09467206228711138,
#   'focu': 0.09467206228711138,
#   'time': 0.09467206228711138,
#   'minimis': 0.09467206228711138,
#   'risk': 0.09467206228711138,
#   'peopl': 0.06730569904493126,
#   'passeng': 0.06730569904493126},
#  '"While we are heavily booked over the next two weeks, there has been a notable drop in forward bookings towards the end of March, into early April.': {'while': 0.07438519179701608,
#   'heavili': 0.07438519179701608,
#   'book': 0.14877038359403216,
#   'next': 0.07438519179701608,
#   'two': 0.07438519179701608,
#   'week': 0.07438519179701608,
#   'notabl': 0.07438519179701608,
#   'drop': 0.052883049249588844,
#   'forward': 0.07438519179701608,
#   'toward': 0.07438519179701608,
#   'end': 0.052883049249588844,
#   'march': 0.031380906702161614,
#   'earli': 0.07438519179701608,
#   'april': 0.052883049249588844},
#  '"It makes sense to selectively prune our schedule to and from those airports where travel has been most affected by the Covid-19 outbreak."': {'it': 0.10413926851582252,
#   'make': 0.10413926851582252,
#   'sens': 0.10413926851582252,
#   'select': 0.10413926851582252,
#   'prune': 0.10413926851582252,
#   'schedul': 0.10413926851582252,
#   'airport': 0.10413926851582252,
#   'travel': 0.04393326938302627,
#   'affect': 0.05642714304385626,
#   'outbreak': 0.10413926851582252},
#  'The firm declined to say how many flights or passengers would be affected.': {'the': 0.1157102983509139,
#   'firm': 0.1157102983509139,
#   'declin': 0.1157102983509139,
#   'say': 0.1157102983509139,
#   'mani': 0.1157102983509139,
#   'flight': 0.0380469645358007,
#   'passeng': 0.08226252105491598,
#   'would': 0.06269682560428472,
#   'affect': 0.06269682560428472},
#  'However, it said the move would not affect its results for the financial year which ends on 31 March.': {'howev': 0.10413926851582252,
#   'said': 0.05642714304385626,
#   'move': 0.10413926851582252,
#   'would': 0.05642714304385626,
#   'affect': 0.05642714304385626,
#   'result': 0.10413926851582252,
#   'financi': 0.10413926851582252,
#   'year': 0.10413926851582252,
#   'end': 0.07403626894942439,
#   'march': 0.04393326938302627},
#  'British Airways said it would contact customers on cancelled flights to offer rebooking on to other carriers, refunds or another flight with BA for a later date of travel.': {'british': 0.043550746440837874,
#   'airway': 0.043550746440837874,
#   'said': 0.03319243708462132,
#   'would': 0.03319243708462132,
#   'contact': 0.06125839324460148,
#   'custom': 0.06125839324460148,
#   'cancel': 0.03319243708462132,
#   'flight': 0.04028502127320074,
#   'offer': 0.06125839324460148,
#   'rebook': 0.06125839324460148,
#   'carrier': 0.06125839324460148,
#   'refund': 0.06125839324460148,
#   'anoth': 0.06125839324460148,
#   'ba': 0.043550746440837874,
#   'later': 0.06125839324460148,
#   'date': 0.06125839324460148,
#   'travel': 0.025843099637074273}}

# %%
vectorizer = TfidfVectorizer(stop_words="english")
transformed = vectorizer.fit_transform(sentences)
tfidf_transformer=TfidfTransformer(use_idf=True)
tfidf_transformer.fit(transformed)
# Out:
# TfidfTransformer()

# %%
tfidf_transformer.idf_
# Out:
# array([2.79175947, 2.79175947, 2.79175947, 2.79175947, 2.79175947,
#        2.79175947, 2.79175947, 2.79175947, 2.38629436, 2.79175947,
#        2.38629436, 2.79175947, 2.38629436, 2.79175947, 2.38629436,
#        2.79175947, 2.79175947, 2.79175947, 2.79175947, 2.79175947,
#        2.38629436, 2.79175947, 2.79175947, 2.38629436, 2.79175947,
#        2.79175947, 2.79175947, 2.79175947, 2.38629436, 2.79175947,
#        2.79175947, 2.79175947, 2.79175947, 2.79175947, 2.79175947,
#        2.79175947, 2.79175947, 2.79175947, 2.79175947, 2.79175947,
#        2.79175947, 2.79175947, 2.79175947, 2.79175947, 2.79175947,
#        2.79175947, 2.79175947, 1.69314718, 2.79175947, 2.79175947,
#        2.79175947, 2.79175947, 2.79175947, 2.79175947, 2.79175947,
#        2.79175947, 2.79175947, 2.38629436, 2.79175947, 2.79175947,
#        2.79175947, 2.79175947, 2.79175947, 1.87546874, 2.79175947,
#        2.79175947, 2.79175947, 2.79175947, 2.79175947, 2.79175947,
#        2.79175947, 2.79175947, 2.38629436, 2.38629436, 2.79175947,
#        2.79175947, 2.79175947, 2.79175947, 2.79175947, 2.79175947,
#        2.79175947, 2.09861229, 2.09861229, 2.79175947, 2.79175947,
#        2.79175947, 2.79175947, 2.79175947, 2.79175947, 2.79175947,
#        2.79175947, 1.87546874, 2.79175947, 2.79175947, 2.79175947,
#        2.79175947, 2.79175947])

# %% [markdown]
# ### Score the sentences

# %%
"""
score a sentence by its word's TF
Basic algorithm: adding the TF frequency of every non-stop word
in a sentence divided by total no of words in a sentence.
"""
###

s_sum={}

for bgn,wf in tf_idf_matrix.items():
    s_sum[bgn] = sum(wf.values())/len(wf)

# %% [markdown]
# ### Find the threshold

# %%
"""
Find the average score from the sentence value dictionary
"""
###
suum = sum(s_sum.values())
average_score = suum/len(s_sum)
print("averagge score :",average_score)
# Out:
# averagge score : 0.08035694323999669

# %% [markdown]
# #### Select a sentence for a summarization if the sentence score is more than the average score

# %%
s_sum
# Out:
# {'British Airways and budget rival Ryanair have cancelled hundreds of flights as demand for travel drops amid fears about the spread of coronavirus.': 0.05405110128717399,
#  'BA is cancelling 216 flights from 16-28 March from London to destinations including New York, Italy, France, Austria, Belgium, Germany and Ireland.': 0.058847462380719,
#  'Ryanair will cut up to 25% of flights in and out of Italy from 17 March to 8 April.': 0.09908652426593785,
#  'Tourists and business people are cutting back on foreign travel.': 0.12419650639697245,
#  'There could be a "very significant expansion" of the number of cases of coronavirus in the UK, Prime Minister Boris Johnson has warned.': 0.07832588704966238,
#  'Ryanair boss Michael O\'Leary said: "Our focus at this time is on minimising any risk to our people and our passengers.': 0.08181005814853874,
#  '"While we are heavily booked over the next two weeks, there has been a notable drop in forward bookings towards the end of March, into early April.': 0.07201908315843608,
#  '"It makes sense to selectively prune our schedule to and from those airports where travel has been most affected by the Covid-19 outbreak."': 0.09334745605534626,
#  'The firm declined to say how many flights or passengers would be affected.': 0.09158384761709507,
#  'However, it said the move would not affect its results for the financial year which ends on 31 March.': 0.0807947310043132,
#  'British Airways said it would contact customers on cancelled flights to offer rebooking on to other carriers, refunds or another flight with BA for a later date of travel.': 0.04986371827576858}

# %%
###
summary=" "
for sentence in sentences:
    if(s_sum[sentence]>=average_score):
        summary +=" "+sentence

summary
# Out:
# '  Ryanair will cut up to 25% of flights in and out of Italy from 17 March to 8 April. Tourists and business people are cutting back on foreign travel. Ryanair boss Michael O\'Leary said: "Our focus at this time is on minimising any risk to our people and our passengers. "It makes sense to selectively prune our schedule to and from those airports where travel has been most affected by the Covid-19 outbreak." The firm declined to say how many flights or passengers would be affected. However, it said the move would not affect its results for the financial year which ends on 31 March.'
